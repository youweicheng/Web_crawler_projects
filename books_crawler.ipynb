# %% [markdown]
# # two way to get books' info
# # 1. xpath
# # 2. beautifulsoup

# %%
from bs4 import  BeautifulSoup
import requests
from lxml import etree
import json


class BookSpider(object):

    def __init__(self):

        self.basic_url = "https://www.books.com.tw/web/cebook_new/?o=1&v=1&page={}"

        self.headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"
                        }

        self.book_data = []

    def get_response(self, url):

        data = requests.get(url, headers=self.headers).content.decode("utf-8")

        # print(data)

        return data

    def parse_data_xpath(self, data):

        data_xpath = etree.HTML(data)

        book_title = data_xpath.xpath('//div[@class="item"]')

        # print(len(book_title))

        for book in book_title:

            book_dict = dict()

            book_dict["book_name"] = book.xpath('.//div[@class = "msg"]/h4/a/text()')[0]
            # print(book_dict)
            book_dict["book_author"] = book.xpath('.//div[@class = "msg"]//li[@class = "info"]/a/text()')[0]
            # print(book_dict)
            book_dict["book_pic"] = book.xpath('.//a/img/@src')[0]
            # print(book_dict)
            try:
                book_dict["book_info"] = (book.xpath('.//p/text()'))[0]
            except IndexError:
                book_dict["book_info"] = "no info"

            self.book_data.append(book_dict)
        print(self.book_data)

    def parse_data_bs4(self, data):

        soup = BeautifulSoup(data, "lxml")

        book_list = soup.select("div.item")

        for book in book_list:

            book_dict = {}
            try:
                book_dict["book_name"] = book.select_one("div.msg a").get_text()
            except AttributeError:
                break

            book_dict["book_author"] = book.select_one("li.info a").get_text()

            book_dict["book_info"] = book.select_one("div.txt_cont p").get_text()

            book_dict["book_pic"] = book.select_one(".cover").get('src')

            self.book_data.append(book_dict)

        print(self.book_data)

    def save_data(self):

        json.dump(self.book_data, open("books_json.json", "w"))

    def run(self):

        for i in range(1, 2):

            url = self.basic_url.format(i)

            data = self.get_response(url)
            self.parse_data_xpath(data)
            # self.parse_data_bs4(data)
        self.save_data()

    # other way to get url

    # def get_url_list(self):
    #
    #     url_list = []
    #
    #     self.basic_url = "https://www.books.com.tw/web/cebook_new/?o=1&v=1&page={}"
    #
    #     for i in range(1,2):
    #         url = self.basic_url.format(i)
    #         url_list.append(url)
    #     return url_list


BookSpider().run()
# Out:
# [{'book_name': '黑魔法糖果店3：超倒楣軟糖 (電子書)', 'book_author': '草野昭子', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127049.jpg&v=62341bac&w=170&h=170', 'book_info': '～用一點點暗黑魔法，化解孩子壞情緒、解開人際心結～\n小朋友，有什麼煩惱嗎？\n愛欺負人的姊姊、跟屁蟲弟弟、愛到處捉弄人的同學……\n跟著巫婆給的小技巧，做出詛咒之糖，\n讓討厭的人都受到懲罰吧！\n\xa0\n'}, {'book_name': '黑魔法糖果店2：惡作劇汽水糖 (電子書)', 'book_author': '草野昭子', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127071.jpg&v=623439e7&w=170&h=170', 'book_info': '～用一點點暗黑魔法，化解孩子壞情緒、解開人際心結～\n小朋友，有什麼煩惱嗎？\n愛欺負人的姊姊、跟屁蟲弟弟、愛到處捉弄人的同學……\n跟著巫婆給的小技巧，做出詛咒之糖，\n讓討厭的人都受到懲罰吧！\n煩'}, {'book_name': '學習高手：哈佛、耶魯雙學霸的最強學習法 (電子書)', 'book_author': '李柘遠LEO', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127065.jpg&v=6234300f&w=170&h=170', 'book_info': '學習需要挑戰天性，也需要付出努力，而好的學習方法可以讓我們提高學習效率，取得更好的學習效果。《學習高手》這本書提供了有效的學習方法，促進我們自主學習，成為一個終身學習者。——樊'}, {'book_name': '日本第一女公關的人際溝通術：不靠靈巧也能創造億萬業績的祕密 (電子書)', 'book_author': 'Enrike（小川愛莉）', 'book_pic': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127056.jpg&v=6234300e&w=170&h=170', 'book_info': '★著作累計突破130,000冊！\n原本相貌普通、內向老實的她，為何能成為日本No.1女公關？\n小川愛莉大方揭露：提升自信、溝通技巧與備受信賴的祕密！\n14年經驗淬鍊，比京都貴婦更周到的信賴'}, {'book_name': '意念使用手冊：瞬間改變時間和空間的量子習慣 (電子書)', 'book_author': '村松大輔', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127057.jpg&v=6234300e&w=170&h=170', 'book_info': '意念掌控行為，行為決定未來！\nAMAZON百大暢銷書，科學實證的自我改變法！\n覺得自己沒有才能、運氣不好、萬事不順遂嗎？\n人生可以砍掉重練，奇蹟確實會發生。\n本書帶你開啟體內的量'}, {'book_name': '無，生命的最佳狀態：用科學方法消除痛苦與不安 (電子書)', 'book_author': '鈴木祐', 'book_pic': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127058.jpg&v=6234300e&w=170&h=170', 'book_info': '閱讀過十萬篇以上科學文獻，\n消化咀嚼才終於找到的｢生命最佳狀態｣！\n改變你看待人生苦難的方式，解開害你受苦的腳鐐，\n讓你不再被「第二枝箭」射中，能自由美好的發揮生命潛能！\n★'}, {'book_name': '原生家庭木馬快篩：三步驟解鎖並拋棄繼承家族負向印記 (電子書)', 'book_author': '李欣頻', 'book_pic': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127060.jpg&v=6234300f&w=170&h=170', 'book_info': '絕大多數的人生問題，都與原生家庭息息相關，\n倘若不破解、清除，你所有的努力都會是徒勞！\n探討原生家庭問題的書很多，三步驟高效解決的只有這本！\n若不覺察木馬，只會被困在原生家庭命運模組裡不斷'}, {'book_name': '選擇，不只是選擇：全美決策領域最知名教授，告訴你選項背後的隱藏力量 (電子書)', 'book_author': '艾瑞克・J・強森', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127061.jpg&v=6234300f&w=170&h=170', 'book_info': '★《快思慢想》《雜訊》作者康納曼：必讀！對個人、他人與社會，提供架構更好選擇的重要指南。\n★《心態致勝》作者卡蘿．杜維克：精采揭示了影響你決策的細微卻強大的元素。\n★《恆毅力》作者安'}, {'book_name': '金錢的另一端是「人」：高盛前交易員教你大人、小孩都看得懂的幸福經濟學 (電子書)', 'book_author': '田內學', 'book_pic': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127062.jpg&v=6234300f&w=170&h=170', 'book_info': '＼日本熱銷，金融冠軍書！／\n撇開金錢，只看人，你會發現，經濟其實很簡單。\n因為，金錢的背後必然有「人」，有著為你勞動、使你幸福的人。\n曾身處資本主義正中央、經手過數千億日圓的'}, {'book_name': '全球人才搶著學!密涅瓦的思考習慣訓練 (電子書)', 'book_author': '劉劭穎,李佳達,黃禮宏', 'book_pic': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127064.jpg&v=6234300f&w=170&h=170', 'book_info': '創新教育模式＋根植人心的科學學習法＝\n應對未知挑戰的必修課\n為什麼一所成立不到10年的大學，\n申請難度卻更勝哈佛、史丹佛等名校？\n且看三位密涅瓦人精華揭密！\n密涅瓦憑什麼'}, {'book_name': '歡迎光臨夢境百貨2：找回不再做夢的人 (電子書)', 'book_author': '李美芮', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127067.jpg&v=6234300f&w=170&h=170', 'book_info': '如果夢境是人生休息時分的禮物，\n為什麼有些人不再入夢？\n\xa0\n現象級暢銷小說、百萬讀者認證的療癒故事──\n\xa0\n★系列雙書銷量破百萬冊，啟發韓國書市年度關鍵字「夢」\n★首作榮登博客'}, {'book_name': '我的布娃娃小米 (電子書)', 'book_author': '井本蓉子', 'book_pic': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127069.jpg&v=62343935&w=170&h=170', 'book_info': '★義大利波隆那插畫展，獲獎作者井本蓉子作品★\n一直陪伴在身旁的娃娃，\n是我最喜歡，也最珍惜的朋友，\n無論做什麼，我都要和它永遠在一起！\n\xa0\n麻美從出生那一刻開始，\n就一直和布偶兔小米形'}, {'book_name': '喵太魯刑警 (電子書)', 'book_author': '川田邦子', 'book_pic': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/012/70/E050127072.jpg&v=623439e7&w=170&h=170', 'book_in ...
